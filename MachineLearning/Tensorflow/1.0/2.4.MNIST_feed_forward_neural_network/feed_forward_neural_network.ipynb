# %%
# modify : step by step for fully_connected_feed.py

# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import argparse
import math
import time

from six.moves import xrange

# %%
data_sets = input_data.read_data_sets("/tmp/tensorflow/mnist/input_data/", FLAGS.fake_data)
# Out:
# Extracting /tmp/tensorflow/mnist/input_data/train-images-idx3-ubyte.gz
# Extracting /tmp/tensorflow/mnist/input_data/train-labels-idx1-ubyte.gz
# Extracting /tmp/tensorflow/mnist/input_data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/tensorflow/mnist/input_data/t10k-labels-idx1-ubyte.gz

# %%
# The MNIST dataset has 10 classes, representing the digits 0 through 9.
NUM_CLASSES = 10

# The MNIST images are always 28x28 pixels.
IMAGE_SIZE = 28
IMAGE_PIXELS = IMAGE_SIZE * IMAGE_SIZE

# %%
FLAGS = None

parser = argparse.ArgumentParser()

parser.add_argument(
      '--learning_rate',
      type=float,
      default=0.01,
      help='Initial learning rate.'
)
parser.add_argument(
      '--max_steps',
      type=int,
      default=20000,
      help='Number of steps to run trainer.'
)
parser.add_argument(
      '--hidden1',
      type=int,
      default=128,
      help='Number of units in hidden layer 1.'
)
parser.add_argument(
      '--hidden2',
      type=int,
      default=32,
      help='Number of units in hidden layer 2.'
)
parser.add_argument(
      '--batch_size',
      type=int,
      default=100,
      help='Batch size.  Must divide evenly into the dataset sizes.'
)
parser.add_argument(
      '--input_data_dir',
      type=str,
      default='/tmp/tensorflow/mnist/input_data',
      help='Directory to put the input data.'
)
parser.add_argument(
      '--log_dir',
      type=str,
      default='/tmp/tensorflow/mnist/logs/feed_forward_neural_network',
      help='Directory to put the log data.'
)
parser.add_argument(
      '--fake_data',
      default=False,
      help='If true, uses fake data for unit testing.',
      action='store_true'
)

FLAGS, unparsed = parser.parse_known_args()

# %%
def inference(images, hidden1_units, hidden2_units):
  # Hidden 1
  with tf.name_scope('hidden1'):
    weights = tf.Variable(
        tf.truncated_normal([IMAGE_PIXELS, hidden1_units],
                            stddev=1.0 / math.sqrt(float(IMAGE_PIXELS))),
        name='weights')
    biases = tf.Variable(tf.zeros([hidden1_units]),
                         name='biases')
    hidden1 = tf.nn.relu(tf.matmul(images, weights) + biases)
  # Hidden 2
  with tf.name_scope('hidden2'):
    weights = tf.Variable(
        tf.truncated_normal([hidden1_units, hidden2_units],
                            stddev=1.0 / math.sqrt(float(hidden1_units))),
        name='weights')
    biases = tf.Variable(tf.zeros([hidden2_units]),
                         name='biases')
    hidden2 = tf.nn.relu(tf.matmul(hidden1, weights) + biases)
  # Linear
  with tf.name_scope('softmax_linear'):
    weights = tf.Variable(
        tf.truncated_normal([hidden2_units, NUM_CLASSES],
                            stddev=1.0 / math.sqrt(float(hidden2_units))),
        name='weights')
    biases = tf.Variable(tf.zeros([NUM_CLASSES]),
                         name='biases')
    logits = tf.matmul(hidden2, weights) + biases
  return logits

def evaluation(logits, labels):
  correct = tf.nn.in_top_k(logits, labels, 1)
  # Return the number of true entries.
  return tf.reduce_sum(tf.cast(correct, tf.int32))

# %%
def do_eval(sess,
            eval_correct,
            images_placeholder,
            labels_placeholder,
            data_set):
  # And run one epoch of eval.
  true_count = 0  # Counts the number of correct predictions.
  steps_per_epoch = data_set.num_examples // FLAGS.batch_size
  num_examples = steps_per_epoch * FLAGS.batch_size
  for step in xrange(steps_per_epoch):
    feed_dict = fill_feed_dict(data_set,
                               images_placeholder,
                               labels_placeholder)
    true_count += sess.run(eval_correct, feed_dict=feed_dict)
  precision = float(true_count) / num_examples
  print('  Num examples: %d  Num correct: %d  Precision @ 1: %0.04f' %
        (num_examples, true_count, precision))

# %%
with tf.Graph().as_default():
    
    images_placeholder = tf.placeholder(tf.float32, shape=(FLAGS.batch_size,IMAGE_PIXELS))
    labels_placeholder = tf.placeholder(tf.int32, shape=(FLAGS.batch_size))

        # Build a Graph that computes predictions from the inference model.
    logits = inference(images_placeholder,
                             FLAGS.hidden1,
                             FLAGS.hidden2)

    # Add to the Graph the Ops for loss calculation.
    labels = tf.to_int64(labels_placeholder)

    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits, name='xentropy')
    loss = tf.reduce_mean(cross_entropy, name='xentropy_mean')

    tf.summary.scalar('loss', loss)
    optimizer = tf.train.GradientDescentOptimizer(FLAGS.learning_rate)
    global_step = tf.Variable(0, name='global_step', trainable=False)
    train_op = optimizer.minimize(loss, global_step=global_step)
    # Add to the Graph the Ops that calculate and apply gradients.
    #train_op = training(loss, FLAGS.learning_rate)

    # Add the Op to compare the logits to the labels during evaluation.
    eval_correct = evaluation(logits, labels_placeholder)

    # Build the summary Tensor based on the TF collection of Summaries.
    summary = tf.summary.merge_all()

    # Add the variable initializer Op.
    init = tf.global_variables_initializer()

    # Create a saver for writing training checkpoints.
    saver = tf.train.Saver()

    # Create a session for running Ops on the Graph.
    sess = tf.Session()

    # Instantiate a SummaryWriter to output summaries and the Graph.
    summary_writer = tf.summary.FileWriter(FLAGS.log_dir, sess.graph)

    # And then after everything is built:

    # Run the Op to initialize the variables.
    sess.run(init)

    # Start the training loop.
    for step in xrange(FLAGS.max_steps):
      start_time = time.time()
        
      images_feed, labels_feed = data_sets.train.next_batch(FLAGS.batch_size,FLAGS.fake_data)
      #images_feed, labels_feed = data_sets.train.next_batch(FLAGS.batch_size)
    
      feed_dict = {
          images_placeholder: images_feed,
          labels_placeholder: labels_feed,
      }

      _, loss_value = sess.run([train_op, loss],feed_dict=feed_dict)

      duration = time.time() - start_time

      # Write the summaries and print an overview fairly often.
      if step % 100 == 0:
        # Print status to stdout.
        print('Step %d: loss = %.2f (%.3f sec)' % (step, loss_value, duration))
        # Update the events file.
        summary_str = sess.run(summary, feed_dict=feed_dict)
        summary_writer.add_summary(summary_str, step)
        summary_writer.flush()

      # Save a checkpoint and evaluate the model periodically.
      if (step + 1) % 1000 == 0 or (step + 1) == FLAGS.max_steps:
        checkpoint_file = os.path.join(FLAGS.log_dir, 'model.ckpt')
        saver.save(sess, checkpoint_file, global_step=step)
        # Evaluate against the training set.
        print('Training Data Eval:')
        do_eval(sess,
                eval_correct,
                images_placeholder,
                labels_placeholder,
                data_sets.train)
        # Evaluate against the validation set.
        print('Validation Data Eval:')
        do_eval(sess,
                eval_correct,
                images_placeholder,
                labels_placeholder,
                data_sets.validation)
        # Evaluate against the test set.
        print('Test Data Eval:')
        do_eval(sess,
                eval_correct,
                images_placeholder,
                labels_placeholder,
                data_sets.test)
# Out:
# Step 0: loss = 2.31 (0.016 sec)
# Step 100: loss = 2.10 (0.000 sec)
# Step 200: loss = 1.80 (0.000 sec)
# Step 300: loss = 1.46 (0.000 sec)
# Step 400: loss = 1.23 (0.000 sec)
# Step 500: loss = 0.81 (0.000 sec)
# Step 600: loss = 0.70 (0.016 sec)
# Step 700: loss = 0.67 (0.000 sec)
# Step 800: loss = 0.68 (0.000 sec)
# Step 900: loss = 0.46 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 47598  Precision @ 1: 0.8654
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4372  Precision @ 1: 0.8744
# Test Data Eval:
#   Num examples: 10000  Num correct: 8718  Precision @ 1: 0.8718
# Step 1000: loss = 0.58 (0.016 sec)
# Step 1100: loss = 0.44 (0.094 sec)
# Step 1200: loss = 0.57 (0.000 sec)
# Step 1300: loss = 0.41 (0.016 sec)
# Step 1400: loss = 0.46 (0.000 sec)
# Step 1500: loss = 0.31 (0.000 sec)
# Step 1600: loss = 0.36 (0.000 sec)
# Step 1700: loss = 0.53 (0.000 sec)
# Step 1800: loss = 0.31 (0.000 sec)
# Step 1900: loss = 0.34 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 49271  Precision @ 1: 0.8958
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4523  Precision @ 1: 0.9046
# Test Data Eval:
#   Num examples: 10000  Num correct: 9000  Precision @ 1: 0.9000
# Step 2000: loss = 0.46 (0.016 sec)
# Step 2100: loss = 0.34 (0.000 sec)
# Step 2200: loss = 0.34 (0.094 sec)
# Step 2300: loss = 0.43 (0.000 sec)
# Step 2400: loss = 0.21 (0.016 sec)
# Step 2500: loss = 0.22 (0.000 sec)
# Step 2600: loss = 0.33 (0.000 sec)
# Step 2700: loss = 0.20 (0.000 sec)
# Step 2800: loss = 0.26 (0.000 sec)
# Step 2900: loss = 0.26 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 50042  Precision @ 1: 0.9099
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4587  Precision @ 1: 0.9174
# Test Data Eval:
#   Num examples: 10000  Num correct: 9148  Precision @ 1: 0.9148
# Step 3000: loss = 0.41 (0.016 sec)
# Step 3100: loss = 0.28 (0.000 sec)
# Step 3200: loss = 0.39 (0.000 sec)
# Step 3300: loss = 0.29 (0.078 sec)
# Step 3400: loss = 0.20 (0.000 sec)
# Step 3500: loss = 0.34 (0.016 sec)
# Step 3600: loss = 0.37 (0.000 sec)
# Step 3700: loss = 0.30 (0.000 sec)
# Step 3800: loss = 0.23 (0.000 sec)
# Step 3900: loss = 0.20 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 50518  Precision @ 1: 0.9185
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4631  Precision @ 1: 0.9262
# Test Data Eval:
#   Num examples: 10000  Num correct: 9218  Precision @ 1: 0.9218
# Step 4000: loss = 0.41 (0.031 sec)
# Step 4100: loss = 0.33 (0.000 sec)
# Step 4200: loss = 0.22 (0.000 sec)
# Step 4300: loss = 0.32 (0.000 sec)
# Step 4400: loss = 0.22 (0.109 sec)
# Step 4500: loss = 0.26 (0.000 sec)
# Step 4600: loss = 0.28 (0.016 sec)
# Step 4700: loss = 0.20 (0.016 sec)
# Step 4800: loss = 0.28 (0.000 sec)
# Step 4900: loss = 0.30 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 50854  Precision @ 1: 0.9246
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4656  Precision @ 1: 0.9312
# Test Data Eval:
#   Num examples: 10000  Num correct: 9263  Precision @ 1: 0.9263
# Step 5000: loss = 0.27 (0.031 sec)
# Step 5100: loss = 0.15 (0.000 sec)
# Step 5200: loss = 0.30 (0.016 sec)
# Step 5300: loss = 0.45 (0.000 sec)
# Step 5400: loss = 0.42 (0.000 sec)
# Step 5500: loss = 0.27 (0.078 sec)
# Step 5600: loss = 0.23 (0.000 sec)
# Step 5700: loss = 0.15 (0.000 sec)
# Step 5800: loss = 0.16 (0.000 sec)
# Step 5900: loss = 0.24 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 51168  Precision @ 1: 0.9303
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4677  Precision @ 1: 0.9354
# Test Data Eval:
#   Num examples: 10000  Num correct: 9302  Precision @ 1: 0.9302
# Step 6000: loss = 0.28 (0.016 sec)
# Step 6100: loss = 0.15 (0.000 sec)
# Step 6200: loss = 0.19 (0.016 sec)
# Step 6300: loss = 0.36 (0.000 sec)
# Step 6400: loss = 0.25 (0.000 sec)
# Step 6500: loss = 0.14 (0.000 sec)
# Step 6600: loss = 0.28 (0.094 sec)
# Step 6700: loss = 0.21 (0.000 sec)
# Step 6800: loss = 0.16 (0.016 sec)
# Step 6900: loss = 0.18 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 51420  Precision @ 1: 0.9349
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4694  Precision @ 1: 0.9388
# Test Data Eval:
#   Num examples: 10000  Num correct: 9345  Precision @ 1: 0.9345
# Step 7000: loss = 0.20 (0.016 sec)
# Step 7100: loss = 0.19 (0.016 sec)
# Step 7200: loss = 0.10 (0.000 sec)
# Step 7300: loss = 0.20 (0.000 sec)
# Step 7400: loss = 0.24 (0.000 sec)
# Step 7500: loss = 0.16 (0.000 sec)
# Step 7600: loss = 0.22 (0.000 sec)
# Step 7700: loss = 0.14 (0.094 sec)
# Step 7800: loss = 0.25 (0.000 sec)
# Step 7900: loss = 0.26 (0.016 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 51576  Precision @ 1: 0.9377
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4708  Precision @ 1: 0.9416
# Test Data Eval:
#   Num examples: 10000  Num correct: 9381  Precision @ 1: 0.9381
# Step 8000: loss = 0.20 (0.016 sec)
# Step 8100: loss = 0.08 (0.016 sec)
# Step 8200: loss = 0.19 (0.016 sec)
# Step 8300: loss = 0.17 (0.000 sec)
# Step 8400: loss = 0.21 (0.000 sec)
# Step 8500: loss = 0.15 (0.000 sec)
# Step 8600: loss = 0.10 (0.000 sec)
# Step 8700: loss = 0.24 (0.000 sec)
# Step 8800: loss = 0.24 (0.094 sec)
# Step 8900: loss = 0.15 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 51836  Precision @ 1: 0.9425
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4723  Precision @ 1: 0.9446
# Test Data Eval:
#   Num examples: 10000  Num correct: 9416  Precision @ 1: 0.9416
# Step 9000: loss = 0.23 (0.016 sec)
# Step 9100: loss = 0.15 (0.000 sec)
# Step 9200: loss = 0.21 (0.000 sec)
# Step 9300: loss = 0.32 (0.000 sec)
# Step 9400: loss = 0.17 (0.000 sec)
# Step 9500: loss = 0.18 (0.000 sec)
# Step 9600: loss = 0.42 (0.000 sec)
# Step 9700: loss = 0.08 (0.000 sec)
# Step 9800: loss = 0.14 (0.000 sec)
# Step 9900: loss = 0.16 (0.078 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52070  Precision @ 1: 0.9467
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4741  Precision @ 1: 0.9482
# Test Data Eval:
#   Num examples: 10000  Num correct: 9439  Precision @ 1: 0.9439
# Step 10000: loss = 0.09 (0.031 sec)
# Step 10100: loss = 0.24 (0.016 sec)
# Step 10200: loss = 0.30 (0.000 sec)
# Step 10300: loss = 0.26 (0.000 sec)
# Step 10400: loss = 0.15 (0.000 sec)
# Step 10500: loss = 0.18 (0.000 sec)
# Step 10600: loss = 0.22 (0.000 sec)
# Step 10700: loss = 0.17 (0.016 sec)
# Step 10800: loss = 0.13 (0.000 sec)
# Step 10900: loss = 0.16 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52174  Precision @ 1: 0.9486
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4749  Precision @ 1: 0.9498
# Test Data Eval:
#   Num examples: 10000  Num correct: 9456  Precision @ 1: 0.9456
# Step 11000: loss = 0.11 (0.109 sec)
# Step 11100: loss = 0.13 (0.000 sec)
# Step 11200: loss = 0.11 (0.000 sec)
# Step 11300: loss = 0.29 (0.000 sec)
# Step 11400: loss = 0.16 (0.000 sec)
# Step 11500: loss = 0.22 (0.016 sec)
# Step 11600: loss = 0.23 (0.000 sec)
# Step 11700: loss = 0.13 (0.000 sec)
# Step 11800: loss = 0.12 (0.016 sec)
# Step 11900: loss = 0.18 (0.016 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52333  Precision @ 1: 0.9515
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4766  Precision @ 1: 0.9532
# Test Data Eval:
#   Num examples: 10000  Num correct: 9488  Precision @ 1: 0.9488
# Step 12000: loss = 0.14 (0.016 sec)
# Step 12100: loss = 0.12 (0.094 sec)
# Step 12200: loss = 0.12 (0.000 sec)
# Step 12300: loss = 0.16 (0.000 sec)
# Step 12400: loss = 0.14 (0.000 sec)
# Step 12500: loss = 0.17 (0.000 sec)
# Step 12600: loss = 0.08 (0.000 sec)
# Step 12700: loss = 0.23 (0.000 sec)
# Step 12800: loss = 0.14 (0.000 sec)
# Step 12900: loss = 0.17 (0.016 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52519  Precision @ 1: 0.9549
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4776  Precision @ 1: 0.9552
# Test Data Eval:
#   Num examples: 10000  Num correct: 9506  Precision @ 1: 0.9506
# Step 13000: loss = 0.12 (0.000 sec)
# Step 13100: loss = 0.19 (0.000 sec)
# Step 13200: loss = 0.14 (0.094 sec)
# Step 13300: loss = 0.15 (0.000 sec)
# Step 13400: loss = 0.19 (0.000 sec)
# Step 13500: loss = 0.19 (0.000 sec)
# Step 13600: loss = 0.09 (0.000 sec)
# Step 13700: loss = 0.22 (0.000 sec)
# Step 13800: loss = 0.15 (0.000 sec)
# Step 13900: loss = 0.08 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52652  Precision @ 1: 0.9573
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4788  Precision @ 1: 0.9576
# Test Data Eval:
#   Num examples: 10000  Num correct: 9525  Precision @ 1: 0.9525
# Step 14000: loss = 0.09 (0.031 sec)
# Step 14100: loss = 0.10 (0.000 sec)
# Step 14200: loss = 0.10 (0.000 sec)
# Step 14300: loss = 0.10 (0.094 sec)
# Step 14400: loss = 0.09 (0.016 sec)
# Step 14500: loss = 0.30 (0.000 sec)
# Step 14600: loss = 0.30 (0.000 sec)
# Step 14700: loss = 0.17 (0.000 sec)
# Step 14800: loss = 0.08 (0.000 sec)
# Step 14900: loss = 0.17 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52726  Precision @ 1: 0.9587
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4795  Precision @ 1: 0.9590
# Test Data Eval:
#   Num examples: 10000  Num correct: 9554  Precision @ 1: 0.9554
# Step 15000: loss = 0.10 (0.016 sec)
# Step 15100: loss = 0.18 (0.000 sec)
# Step 15200: loss = 0.09 (0.000 sec)
# Step 15300: loss = 0.17 (0.016 sec)
# Step 15400: loss = 0.22 (0.078 sec)
# Step 15500: loss = 0.25 (0.000 sec)
# Step 15600: loss = 0.19 (0.000 sec)
# Step 15700: loss = 0.10 (0.000 sec)
# Step 15800: loss = 0.15 (0.000 sec)
# Step 15900: loss = 0.16 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52783  Precision @ 1: 0.9597
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4797  Precision @ 1: 0.9594
# Test Data Eval:
#   Num examples: 10000  Num correct: 9554  Precision @ 1: 0.9554
# Step 16000: loss = 0.10 (0.031 sec)
# Step 16100: loss = 0.07 (0.000 sec)
# Step 16200: loss = 0.09 (0.000 sec)
# Step 16300: loss = 0.13 (0.016 sec)
# Step 16400: loss = 0.18 (0.000 sec)
# Step 16500: loss = 0.12 (0.094 sec)
# Step 16600: loss = 0.26 (0.000 sec)
# Step 16700: loss = 0.10 (0.000 sec)
# Step 16800: loss = 0.09 (0.000 sec)
# Step 16900: loss = 0.15 (0.016 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 52941  Precision @ 1: 0.9626
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4810  Precision @ 1: 0.9620
# Test Data Eval:
#   Num examples: 10000  Num correct: 9594  Precision @ 1: 0.9594
# Step 17000: loss = 0.13 (0.016 sec)
# Step 17100: loss = 0.11 (0.016 sec)
# Step 17200: loss = 0.06 (0.016 sec)
# Step 17300: loss = 0.09 (0.000 sec)
# Step 17400: loss = 0.13 (0.000 sec)
# Step 17500: loss = 0.08 (0.000 sec)
# Step 17600: loss = 0.05 (0.094 sec)
# Step 17700: loss = 0.25 (0.000 sec)
# Step 17800: loss = 0.16 (0.000 sec)
# Step 17900: loss = 0.07 (0.016 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 53043  Precision @ 1: 0.9644
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4823  Precision @ 1: 0.9646
# Test Data Eval:
#   Num examples: 10000  Num correct: 9601  Precision @ 1: 0.9601
# Step 18000: loss = 0.09 (0.016 sec)
# Step 18100: loss = 0.10 (0.000 sec)
# Step 18200: loss = 0.11 (0.000 sec)
# Step 18300: loss = 0.06 (0.000 sec)
# Step 18400: loss = 0.12 (0.000 sec)
# Step 18500: loss = 0.10 (0.000 sec)
# Step 18600: loss = 0.18 (0.016 sec)
# Step 18700: loss = 0.09 (0.094 sec)
# Step 18800: loss = 0.09 (0.000 sec)
# Step 18900: loss = 0.15 (0.016 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 53206  Precision @ 1: 0.9674
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4820  Precision @ 1: 0.9640
# Test Data Eval:
#   Num examples: 10000  Num correct: 9615  Precision @ 1: 0.9615
# Step 19000: loss = 0.07 (0.016 sec)
# Step 19100: loss = 0.11 (0.000 sec)
# Step 19200: loss = 0.09 (0.000 sec)
# Step 19300: loss = 0.20 (0.016 sec)
# Step 19400: loss = 0.04 (0.000 sec)
# Step 19500: loss = 0.10 (0.000 sec)
# Step 19600: loss = 0.11 (0.000 sec)
# Step 19700: loss = 0.12 (0.000 sec)
# Step 19800: loss = 0.10 (0.078 sec)
# Step 19900: loss = 0.06 (0.000 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 53264  Precision @ 1: 0.9684
# Validation Data Eval:
#   Num examples: 5000  Num correct: 4831  Precision @ 1: 0.9662
# Test Data Eval:
#   Num examples: 10000  Num correct: 9624  Precision @ 1: 0.9624

# %%
sess.close()
